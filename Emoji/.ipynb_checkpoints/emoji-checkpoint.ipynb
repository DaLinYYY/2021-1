# %%
import numpy as np
emoji_array = np.load("emojis_16.npy")
# print(emoji_array)
# Out:
# [[[[2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    ...
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]]
#
#   [[2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    ...
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]]
#
#   [[2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
#    [2.98039228e-01 4.11764711e-01 4.43137258e-01 0.00000000e+00]
# ...

# %%
emoji_mean_array = np.array([value.mean(axis = (0, 1)) for value in emoji_array])
# emoji_mean_array = np.array([value.mean() for value in emoji_array])
print(emoji_mean_array)
print(len(emoji_mean_array))
# Out:
# [[0.38617945 0.40615448 0.39446637 0.4922756 ]
#  [0.30208752 0.35775143 0.28550488 0.492356  ]
#  [0.4085485  0.34248272 0.37241518 0.49226028]
#  ...
#  [0.36950442 0.36950442 0.36950442 0.3864163 ]
#  [0.37840453 0.26212475 0.18097807 0.62275577]
#  [0.31413946 0.31413946 0.31413946 0.6398859 ]]
# 1506

# %%
from scipy import spatial

# %%
a = np.array([[1, 2, 4 ,3] ,[4 ,5 ,6 ,7]])
print(type(a))
tree = spatial.KDTree(a)
tree.data
# Out:
# <class 'numpy.ndarray'>
# array([[1, 2, 4, 3],
#        [4, 5, 6, 7]])

# %%
pts = np.array([[1, 5, 1, 1], [4, 5, 1, 7]])
tree.query(pts[1])
# Out:
# (5.0, 1)
